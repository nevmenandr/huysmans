# %%
from pathlib import Path
import os
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import seaborn as sns
import pylab

# %%
data = []
base_dir = 'corpus_preprocessed'

for target in ['aimait', 'terribles']:
    target_label = 1 if target == 'aimait' else 0
    
    target_dir = os.path.join(base_dir, target)
    
    for author in os.listdir(target_dir):
        author_dir = os.path.join(target_dir, author)
        
        if os.path.isdir(author_dir):
            for filename in os.listdir(author_dir):
                if filename.endswith('.txt'):
                    file_path = os.path.join(author_dir, filename)
                    
                    with open(file_path, 'r', encoding='utf-8') as file:
                        text = file.read()
                    data.append({
                        'target': target_label,
                        'author': author,
                        'title': filename[:-4],
                        'text': text
                    })

df = pd.DataFrame(data)
display(df)
# Out:
#      target      author                title  \
# 0         1  prudentius          prud.psycho
# 1         1    sidonius            sidonius3
# 2         1    sidonius            sidonius2
# 3         1    sidonius            sidonius1
# 4         1    sidonius            sidonius5
# ..      ...         ...                  ...
# 893       0     tacitus            tac.ann15
# 894       0     tacitus            tac.ann11
# 895       0     tacitus            tac.ann12
# 896       0     tacitus            tac.ann13
# 897       0    ammianus  ammianus_res_gestae
#
#                                                   text
# 0    praefatio senex fidelis primus credo uia abram...
# 1    epistula sidonius auitus salus multus uinculum...
# 2    epistula sidonius ecdicio salus duo nunc parit...
# 3    epistula sidonius constantio salus praecipio d...
# 4    epistula sidonius petronius salus audio lectit...
# ..                                                 ...
# 893  interea rex parthi uologaeses cognosco corbulo...
# 894  ualerium asiaticum bis consul quondam adulter ...
# 895  caedes messalinae convulsus princeps domus ori...
# 896  primus nouus principatus mors iunii silanus pr...
# 897  liber caput gallus caesar saeuitia emetior ins...
#
# [898 rows x 4 columns]

# %%
data = []
base_dir = 'other_preprocessed'

for target in ['expected_aimait', 'expected_terribles']:
    target_label = 1 if target == 'expected_aimait' else 0
    
    target_dir = os.path.join(base_dir, target)
    
    for author in os.listdir(target_dir):
        author_dir = os.path.join(target_dir, author)
        
        if os.path.isdir(author_dir):
            for filename in os.listdir(author_dir):
                if filename.endswith('.txt'):
                    file_path = os.path.join(author_dir, filename)
                    
                    with open(file_path, 'r', encoding='utf-8') as file:
                        text = file.read()
                    data.append({
                        'expected target': target_label,
                        'author': author,
                        'title': filename[:-4],
                        'text': text
                    })

df_other = pd.DataFrame(data)
display(df_other)
# Out:
#     expected target      author  \
# 0                 1  dracontius
# 1                 1  dracontius
# 2                 1  dracontius
# 3                 1   eugyppius
# 4                 1   eugyppius
# 5                 1   eugyppius
# 6                 1    mamertus
# 7                 1    mamertus
# 8                 1    mamertus
# 9                 1    ennodius
# 10                1    ennodius
# 11                1    ennodius
# 12                1    ennodius
# 13                1    ennodius
# 14                1    ennodius
# 15                1    ennodius
# 16                1    ennodius
# 17                1    ennodius
# 18                1    ennodius
# 19                1    ennodius
# 20                1    ennodius
# 21                1      avitus
# 22                1      avitus
# 23                1      avitus
# 24                1      avitus
# 25                1      avitus
# 26                1      avitus
# 27                1      avitus
# 28                0    paulinus
# 29                0    paulinus
# 30                0    paulinus
# 31                0     damasus
# 32                0  hieronymus
# 33                0  hieronymus
# 34                0  hieronymus
# 35                0  hieronymus
# 36                0  hieronymus
# 37                0  hieronymus
# 38                0  hieronymus
# 39                0  hieronymus
# 40                0  hieronymus
# 41                0  hieronymus
# 42                0  hieronymus
# 43                0  hieronymus
# 44                0  hieronymus
# 45                0  hieronymus
# 46                0  hieronymus
# 47                0  hieronymus
# 48                0    hilarius
# 49                0    hilarius
# 50                0    hilarius
# 51                0    hilarius
# 52                0    hilarius
# 53                0    hilarius
# 54                0    hilarius
# 55                0    hilarius
# 56                0    hilarius
# 57                0    hilarius
# 58                0    hilarius
# 59                0    hilarius
#
#                                             title  \
# 0                                   carmen_de_deo
# 1                             hexameron_dracontii
# 2                       satisfactio_ad_guntharium
# 3                            vita_sancti_severini
# 4                                       thesaurus
# 5                            epistola_dedicatoria
# 6                       hymnus_de_passione_domini
# 7                                       epistolae
# 8                                 de_statu_animae
# 9              panegyricus_theoderico_regi_dictus
# 10                                      dictiones
# 11                                     petitorium
# 12                                  eucharisticum
# 13                          paraenesis_didascalia
# 14                                      epistolae
# 15                                vita_b._antonii
# 16                                        carmina
# 17                               benedictio_cerei
# 18               libellus_apologeticus_pro_synodo
# 19                              vita_b._epiphanii
# 20                                     praeceptum
# 21                                      fragmenta
# 22                        homilia_de_rogationibus
# 23                                      epistolae
# 24  fragmenta_libri_de_divinitate_spiritus_sancti
# 25                           collatio_episcoporum
# 26                   de_mosaicae_historiae_gestis
# 27                          sermo_in_rogationibus
# 28                                       adversus
# 29                                  vita_ambrosii
# 30                             de_benedictionibus
# 31                                    epigrammata
# 32                              notitia_historica
# 33       de_situ_et_nominibus_locorum_hebraicorum
# 34                             contra_vigilantium
# 35                        apologia_adv_lib_rufini
# 36                           de_viris_illustribus
# 37                                   vita_hilarii
# 38                                 contra_ioannem
# 39                   vita_s._pauli_primi_eremitae
# 40                   dialogus_contra_luciferianos
# 41               quaestiones_hebraicae_in_genesim
# 42           excerpta_de_aliquot_palestinae_locis
# 43                            canticum_canticorum
# 44                     dialogus_contra_pelagianos
# 45                    vita_malchi_monachi_captivi
# 46                       de_virginitate_b._mariae
# 47                            adversus_iovinianum
# 48                                     de_synodis
# 49                                      fragmenta
# 50                            pologetica_responsa
# 51                                 de_dedicatione
# 52                                 contra_arianos
# 53                        secundus_ad_constantium
# 54                           epistola_ad_libellus
# 55                                   de_trinitate
# 56                             contra_constantium
# 57                          primus_ad_constantium
# 58                              epistola_ad_abram
# 59                            hymnus_abrae_missus
#
#                                                  text
# 0   liber primus cupio animus placidus rescio tono...
# 1   sanctus eugenii epistula chindasuintum rex inc...
# 2   satisfactio guntharium rex immense deus cuncto...
# 3   epistula eugyppii paschasium diaconum dominus ...
# 4   tomus prior caput primus sententia iacobi apos...
# 5   epistula dedicatoria excerptor codico nonnullu...
# 6   hymnus passio dominus pango lingua gloriosus p...
# 7   epistula primus claudianus sidonio papae salus...
# 8   praefatio praefectorio patricius doceo bonus u...
# 9   panegyricus theoderico rex dico princeps uener...
# 10  dictio primus natalis laurentii mediolanensis ...
# 11  petitorium deus arbiter uniuersitas conditor r...
# 12  eucharisticum nomen pater filius spiritus sanc...
# 13  paraenesis didascalia deus obsequor convenio m...
# 14  liber primus epistula primus ennodius ioanni s...
# 15  praefatio praeliantes assurgunt buccinis equus...
# 16  liber primus itinerarius brigantio castellum c...
# 17  benedictio cereus dignus iustus uerus dignus i...
# 18  praefatio soleo dico afficio res ardor exigo a...
# 19  uita b epiphanii quamuis urgeo suscipio opus a...
# 20  praeceptum nullus dubius homo carnal concupisc...
# 21  homiliaris octo titulis initium homilia dictum...
# 22  homilia rogatio curro trames uitalis gallia ta...
# 23  epistula primus gundobadum rex burgundio avitu...
# 24  fragmentum liber diuinitas spiritus sanctus sa...
# 25  collatio episcoporum prouidente dominus eccles...
# 26  prologus dominus sancio christus pius beatus a...
# 27  sermo rogatio lego historia rex quidam celebro...
# 28  aduersus coelestium beatitudo tuus iustitia ob...
# 29  uita sanctus ambrosii hortaris uenerabilis pat...
# 30  praefatio sacrosanctus praesagus sancio patria...
# 31  nunc damasi moneo auris praebeo benignus sitio...
# 32  notitia historicus senatus hieronymus liber ui...
# 33  praefatio eusebius beatus pamphilo martyre cog...
# 34  seq liber contra vigilo admonitio contra vigil...
# 35  liber contra rufinum admonitio dissensio hiero...
# 36  seq liber uir illustris admonitio liber illust...
# 37  uita sanctus hilarii hilarus urbs pictauorum a...
# 38  seq liber contra ioannem hierosol admonitio io...
# 39  uita senatus paulus primus eremitae senatus pa...
# 40  sequor liber admonitio notus lucifer calaritan...
# 41  praefatio principia liber debeo sequor opus ar...
# 42  consequor geographicam tabula palaestinae admo...
# 43  canticum canticus cap osculo osculo ora bonus ...
# 44  seq dialogus contra pelagianos admonitio uix o...
# 45  uita malchi monachi captivus malchi monachi ma...
# 46  liber subsequor admonitio heluidius aliquot sa...
# 47  seq liber aduersus iouinianum admonitio iouini...
# 48  liber synodis seu fides orientalis dilectissim...
# 49  fragmentum alius pars fides spes charitas prae...
# 50  apologetica respondeo reprehensor liber synodi...
# 51  sermo dedicatio ecclesia propitio deitas frate...
# 52  liber contra arianos auxentium dilectissimis f...
# 53  liber secundus consto hilarus rex praesens nes...
# 54  epistula seu libellus dauid gloriosus psalmus ...
# 55  liber primus hilarus pono philosophus beatitud...
# 56  exhortatio certo fides tempus loquor praetereo...
# 57  liber primus consto augustus ecclesia frater a...
# 58  epistula abram dilectissimae filia abrae hilar...
# 59  hymnus abrae mitto lucus largitor splendidus s...

# %%
author_list = list(df_other['author'].unique())
print(author_list)
# Out:
# ['dracontius', 'eugyppius', 'mamertus', 'ennodius', 'avitus', 'paulinus', 'damasus', 'hieronymus', 'hilarius']

# %%
author = 'dracontius'
targ = df_other[df_other['author'] == author]['expected target'][0]
targ
# Out:
# 1

# %%
def make_predict_table(author, df_other, models, tfidfs):
    df_temp = df_other[df_other['author'] == author].copy()
    
    targ = df_temp['expected target'].iloc[0] 
    print(f"{author}, expected target: {targ}")

    prediction_table = pd.DataFrame()
    prediction_table['title'] = df_temp['title'].values

    for i, (model, tfidf) in enumerate(zip(models, tfidfs)):
        X = tfidf.transform(df_temp['text']).toarray()
        y_pred = model.predict(X)
        prediction_table[f'Model {i}'] = y_pred

    means = prediction_table.iloc[:, 1:].mean()
    mean_row = pd.DataFrame([['mean'] + list(means)], columns=prediction_table.columns)
    prediction_table = pd.concat([prediction_table, mean_row], ignore_index=True)

    return prediction_table

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.ensemble import AdaBoostClassifier
from sklearn.ensemble import StackingClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.naive_bayes import BernoulliNB
from sklearn.linear_model import RidgeClassifier
from sklearn.svm import SVC

less = min(df.target.value_counts())
balanced_df = pd.concat((df[df['target'] == 0].sample(less, random_state=9), df[df['target'] != 0].sample(less, random_state=9)))

models = []
tfidfs = []

vocab = 50000
ngram = 4
model = AdaBoostClassifier(estimator=LogisticRegression(), n_estimators=100, algorithm='SAMME', random_state=11)
tfidf = TfidfVectorizer(max_features=vocab, ngram_range=(1, ngram))
X = tfidf.fit_transform(balanced_df['text']).toarray()
y = np.asarray(balanced_df['target'])
model.fit(X, y)
models.append(model)
tfidfs.append(tfidf)

vocab = 30000
ngram = 1
model = AdaBoostClassifier(estimator=BernoulliNB(), n_estimators=100, algorithm='SAMME', random_state=11)
tfidf = TfidfVectorizer(max_features=vocab, ngram_range=(1, ngram))
X = tfidf.fit_transform(balanced_df['text']).toarray()
y = np.asarray(balanced_df['target'])
model.fit(X, y)
models.append(model)
tfidfs.append(tfidf)

vocab = 100
ngram = 4
model = RandomForestClassifier()
tfidf = TfidfVectorizer(max_features=vocab, ngram_range=(1, ngram))
X = tfidf.fit_transform(balanced_df['text']).toarray()
y = np.asarray(balanced_df['target'])
model.fit(X, y)
models.append(model)
tfidfs.append(tfidf)

estimators=[('svm', SVC(probability=True)), 
             ('log', LogisticRegression()),
             ('rid', RidgeClassifier(alpha=5))]
vocab = 20000
ngram = 1
model = StackingClassifier(estimators=estimators, final_estimator=RandomForestClassifier())
tfidf = TfidfVectorizer(max_features=vocab, ngram_range=(1, ngram))
X = tfidf.fit_transform(balanced_df['text']).toarray()
y = np.asarray(balanced_df['target'])
model.fit(X, y)
models.append(model)
tfidfs.append(tfidf)

# %%
author = 'dracontius'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# dracontius, expected target: 1
#                        title  Model 0   Model 1  Model 2  Model 3
# 0              carmen_de_deo      1.0  1.000000      1.0      1.0
# 1        hexameron_dracontii      1.0  1.000000      1.0      1.0
# 2  satisfactio_ad_guntharium      1.0  0.000000      1.0      1.0
# 3                       mean      1.0  0.666667      1.0      1.0

# %%
author = 'eugyppius'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# eugyppius, expected target: 1
#                   title   Model 0  Model 1   Model 2   Model 3
# 0  vita_sancti_severini  1.000000      1.0  1.000000  1.000000
# 1             thesaurus  0.000000      1.0  0.000000  0.000000
# 2  epistola_dedicatoria  0.000000      1.0  0.000000  1.000000
# 3                  mean  0.333333      1.0  0.333333  0.666667

# %%
['dracontius', 'eugyppius', 'mamertus', 'ennodius', 'avitus', 'paulinus', 'damasus', 'hieronymus', 'hilarius']

# %%
author = 'mamertus'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# mamertus, expected target: 1
#                        title  Model 0   Model 1   Model 2  Model 3
# 0  hymnus_de_passione_domini      0.0  1.000000  0.000000      1.0
# 1                  epistolae      0.0  0.000000  0.000000      1.0
# 2            de_statu_animae      0.0  0.000000  1.000000      1.0
# 3                       mean      0.0  0.333333  0.333333      1.0

# %%
author = 'ennodius'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# ennodius, expected target: 1
#                                  title  Model 0   Model 1   Model 2  Model 3
# 0   panegyricus_theoderico_regi_dictus     1.00  1.000000  1.000000      1.0
# 1                            dictiones     1.00  1.000000  1.000000      1.0
# 2                           petitorium     0.00  1.000000  0.000000      1.0
# 3                        eucharisticum     1.00  0.000000  1.000000      1.0
# 4                paraenesis_didascalia     1.00  0.000000  1.000000      1.0
# 5                            epistolae     1.00  1.000000  0.000000      1.0
# 6                      vita_b._antonii     1.00  0.000000  1.000000      1.0
# 7                              carmina     1.00  1.000000  1.000000      1.0
# 8                     benedictio_cerei     0.00  1.000000  0.000000      1.0
# 9     libellus_apologeticus_pro_synodo     1.00  1.000000  0.000000      1.0
# 10                   vita_b._epiphanii     1.00  1.000000  1.000000      1.0
# 11                          praeceptum     0.00  0.000000  0.000000      1.0
# 12                                mean     0.75  0.666667  0.583333      1.0

# %%
author = 'avitus'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# avitus, expected target: 1
#                                            title   Model 0   Model 1  \
# 0                                      fragmenta  1.000000  1.000000
# 1                        homilia_de_rogationibus  0.000000  0.000000
# 2                                      epistolae  0.000000  0.000000
# 3  fragmenta_libri_de_divinitate_spiritus_sancti  0.000000  1.000000
# 4                           collatio_episcoporum  1.000000  0.000000
# 5                   de_mosaicae_historiae_gestis  1.000000  1.000000
# 6                          sermo_in_rogationibus  0.000000  0.000000
# 7                                           mean  0.428571  0.428571
#
#     Model 2  Model 3
# 0  1.000000      1.0
# 1  1.000000      1.0
# 2  1.000000      1.0
# 3  0.000000      1.0
# 4  0.000000      1.0
# 5  1.000000      1.0
# 6  0.000000      1.0
# 7  0.571429      1.0

# %%
author = 'paulinus'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# paulinus, expected target: 0
#                 title   Model 0  Model 1  Model 2   Model 3
# 0            adversus  0.000000      1.0      1.0  1.000000
# 1       vita_ambrosii  1.000000      1.0      1.0  1.000000
# 2  de_benedictionibus  0.000000      1.0      1.0  0.000000
# 3                mean  0.333333      1.0      1.0  0.666667

# %%
author = 'damasus'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# damasus, expected target: 0
#          title  Model 0  Model 1  Model 2  Model 3
# 0  epigrammata      1.0      1.0      1.0      1.0
# 1         mean      1.0      1.0      1.0      1.0

# %%
author = 'hieronymus'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# hieronymus, expected target: 0
#                                        title  Model 0  Model 1  Model 2  \
# 0                          notitia_historica   0.0000      0.0      0.0
# 1   de_situ_et_nominibus_locorum_hebraicorum   0.0000      1.0      1.0
# 2                         contra_vigilantium   0.0000      0.0      0.0
# 3                    apologia_adv_lib_rufini   0.0000      0.0      0.0
# 4                       de_viris_illustribus   0.0000      1.0      1.0
# 5                               vita_hilarii   0.0000      1.0      0.0
# 6                             contra_ioannem   0.0000      1.0      1.0
# 7               vita_s._pauli_primi_eremitae   0.0000      0.0      1.0
# 8               dialogus_contra_luciferianos   1.0000      0.0      1.0
# 9           quaestiones_hebraicae_in_genesim   0.0000      1.0      1.0
# 10      excerpta_de_aliquot_palestinae_locis   0.0000      1.0      1.0
# 11                       canticum_canticorum   0.0000      1.0      0.0
# 12                dialogus_contra_pelagianos   0.0000      0.0      0.0
# 13               vita_malchi_monachi_captivi   0.0000      0.0      1.0
# 14                  de_virginitate_b._mariae   0.0000      0.0      0.0
# 15                       adversus_iovinianum   0.0000      1.0      0.0
# 16                                      mean   0.0625      0.5      0.5
#
#     Model 3
# 0     0.000
# 1     0.000
# 2     0.000
# 3     0.000
# 4     1.000
# 5     1.000
# 6     0.000
# 7     1.000
# 8     1.000
# 9     0.000
# 10    1.000
# 11    0.000
# 12    0.000
# 13    1.000
# 14    0.000
# 15    0.000
# 16    0.375

# %%
author = 'hilarius'
make_predict_table(author, df_other, models, tfidfs)
# Out:
# hilarius, expected target: 0
#                       title   Model 0   Model 1  Model 2   Model 3
# 0                de_synodis  1.000000  0.000000     1.00  1.000000
# 1                 fragmenta  0.000000  0.000000     0.00  1.000000
# 2       pologetica_responsa  0.000000  1.000000     0.00  1.000000
# 3            de_dedicatione  0.000000  1.000000     0.00  1.000000
# 4            contra_arianos  1.000000  0.000000     1.00  1.000000
# 5   secundus_ad_constantium  0.000000  0.000000     0.00  0.000000
# 6      epistola_ad_libellus  1.000000  0.000000     0.00  0.000000
# 7              de_trinitate  1.000000  1.000000     1.00  1.000000
# 8        contra_constantium  1.000000  0.000000     0.00  0.000000
# 9     primus_ad_constantium  0.000000  0.000000     0.00  0.000000
# 10        epistola_ad_abram  0.000000  0.000000     0.00  0.000000
# 11      hymnus_abrae_missus  0.000000  1.000000     0.00  1.000000
# 12                     mean  0.416667  0.333333     0.25  0.583333
